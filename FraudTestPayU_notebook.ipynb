# %% [markdown]
# -- Made by Maria Sierra
# ## 1. Load dataset from MySql

# %%
# GET A SAMPLE IN ORDER TO ACHIEVE THE LOAD TO MYSQL

import pandas as pd
import numpy as np

#df = pd.read_csv('FraudTestPayU.csv',low_memory=False)

#df = df.sample(frac=0.25)

#df.to_csv('sample_fraud_test_df.csv', index = False, encoding = 'utf-8') #this one it is load to mysql

# %%
#!pip3 install pymysql

# %%
import pymysql as sql

# %%
##variables
db_name = "testfraud"
db_host = "localhost"
db_username = "root"
db_pwd = "BDnotengo.26"

# %%
try: 
    conn = sql.connect(host= db_host,
                           port = int(3306),
                           user = db_username,
                           passwd = db_pwd,
                           db = db_name
    )
except z:
    print(z)

# %%
if conn:
    print("Database connected")
else:
    print("Error")
# Out:
# Database connected

# %% [markdown]
# ## 1.1. Reading dataframe

# %%
df = pd.read_sql_query("SELECT * FROM sample_fraud_test_df", conn)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_17512\891040658.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM sample_fraud_test_df", conn)

# %%
df.info()
#non null values there
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55834 entries, 0 to 55833
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           55834 non-null  int64
#  1   Unnamed: 0             55834 non-null  int64
#  2   trans_date_trans_time  55834 non-null  datetime64[ns]
#  3   cc_num                 55834 non-null  int64
#  4   merchant               55834 non-null  object
#  5   category               55834 non-null  object
#  6   amt                    55834 non-null  float64
#  7   first                  55834 non-null  object
#  8   last                   55834 non-null  object
#  9   gender                 55834 non-null  object
#  10  street                 55834 non-null  object
#  11  city                   55834 non-null  object
#  12  state                  55834 non-null  object
#  13  zip                    55834 non-null  int64
#  14  lat                    55834 non-null  float64
#  15  long                   55834 non-null  float64
#  16  city_pop               55834 non-null  int64
#  17  job                    55834 non-null  object
#  18  dob                    55834 non-null  object
#  19  trans_num              55834 non-null  object
#  20  unix_time              55834 non-null  int64
#  21  merch_lat              55834 non-null  float64
#  22  merch_long             55834 non-null  float64
#  23  is_fraud               55834 non-null  int64
#  24  currency               55834 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(7), object(12)
# memory usage: 10.6+ MB

# %%
df.describe().T
# Out:
#                 count          mean           std           min           25%  \
# Unnamed: 0.1  55834.0  2.779064e+05  1.601825e+05  1.600000e+01  1.389840e+05
# Unnamed: 0    55834.0  2.779064e+05  1.601825e+05  1.600000e+01  1.389840e+05
# cc_num        55834.0  4.244513e+17  1.318859e+18  6.041621e+10  1.800429e+14
# amt           55834.0  6.891974e+01  1.360487e+02  1.000000e+00  9.670000e+00
# zip           55834.0  4.892836e+04  2.687067e+04  1.257000e+03  2.629200e+04
# lat           55834.0  3.855514e+01  5.056267e+00  2.002710e+01  3.469020e+01
# long          55834.0 -9.026596e+01  1.378798e+01 -1.656723e+02 -9.679090e+01
# city_pop      55834.0  8.579480e+04  2.901206e+05  2.300000e+01  7.430000e+02
# unix_time     55834.0  1.380683e+09  5.197050e+06  1.371817e+09  1.376030e+09
# merch_lat     55834.0  3.855784e+01  5.091865e+00  1.905776e+01  3.477963e+01
# merch_long    55834.0 -9.026524e+01  1.379730e+01 -1.666707e+02 -9.691425e+01
# is_fraud      55834.0  3.779059e-03  6.135834e-02  0.000000e+00  0.000000e+00
#
#                        50%           75%           max
# Unnamed: 0.1  2.786890e+05  4.167782e+05  5.557140e+05
# Unnamed: 0    2.786890e+05  4.167782e+05  5.557140e+05
# cc_num        3.521815e+15  4.642255e+15  4.992346e+18
# amt           4.752500e+01  8.329750e+01  6.111780e+03
# zip           4.817400e+04  7.204200e+04  9.978300e+04
# lat           3.937160e+01  4.184670e+01  6.568990e+01
# long         -8.747690e+01 -8.017520e+01 -6.795030e+01
# city_pop      2.435000e+03  2.032800e+04  2.906700e+06
# unix_time     1.380807e+09  1.385867e+09  1.388534e+09
# merch_lat     3.938387e+01  4.194431e+01  6.664440e+01
# merch_long   -8.744304e+01 -8.025616e+01 -6.695736e+01
# is_fraud      0.000000e+00  0.000000e+00  1.000000e+00

# %% [markdown]
# ## 2. From 'category' extract the ones which only have less than 15000 entries
#
# Sample fraction is 0.25.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(y = 'category', 
              data= df, order=df['category'].value_counts().index);
plt.title('Barplot categories')
plt.ylabel('Categories')
plt.xlabel('Counter')
# Out:
# Text(0.5, 0, 'Counter')

# %%
cat_count = df['category'].value_counts() #frac = 0.25 15000*0.25 = 3750; entries higher than 3750 will be dropped
cat_count
# Out:
# gas_transport     5835
# home              5301
# grocery_pos       5271
# shopping_pos      5023
# kids_pets         4865
# shopping_net      4183
# entertainment     4046
# personal_care     3951
# food_dining       3926
# health_fitness    3611
# misc_pos          3487
# misc_net          2713
# grocery_net       1931
# travel            1691
# Name: category, dtype: int64

# %%
df.drop(df[(df['category']== 'gas_transport')|
            (df['category']== 'home')|
            (df['category']== 'grocery_pos')| 
            (df['category']== 'shopping_pos')|
            (df['category']== 'kids_pets')|
            (df['category']== 'shopping_net')|
            (df['category']== 'entertainment')|
            (df['category']== 'personal_care')|
            (df['category']== 'food_dining')].index, inplace = True)


df['category'].value_counts()
# Out:
# health_fitness    3611
# misc_pos          3487
# misc_net          2713
# grocery_net       1931
# travel            1691
# Name: category, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13433 entries, 6 to 55832
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           13433 non-null  int64
#  1   Unnamed: 0             13433 non-null  int64
#  2   trans_date_trans_time  13433 non-null  datetime64[ns]
#  3   cc_num                 13433 non-null  int64
#  4   merchant               13433 non-null  object
#  5   category               13433 non-null  object
#  6   amt                    13433 non-null  float64
#  7   first                  13433 non-null  object
#  8   last                   13433 non-null  object
#  9   gender                 13433 non-null  object
#  10  street                 13433 non-null  object
#  11  city                   13433 non-null  object
#  12  state                  13433 non-null  object
#  13  zip                    13433 non-null  int64
#  14  lat                    13433 non-null  float64
#  15  long                   13433 non-null  float64
#  16  city_pop               13433 non-null  int64
#  17  job                    13433 non-null  object
#  18  dob                    13433 non-null  object
#  19  trans_num              13433 non-null  object
#  20  unix_time              13433 non-null  int64
#  21  merch_lat              13433 non-null  float64
#  22  merch_long             13433 non-null  float64
#  23  is_fraud               13433 non-null  int64
#  24  currency               13433 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(7), object(12)
# memory usage: 2.7+ MB

# %% [markdown]
# ##  3. API requests to exchange rate
# ### FROM https://github.com/Formicka/exchangerate.host/blob/master/README.md
#
# Currency conversion endpoint, can be used to convert any amount from one currency to another -- bellow variable $response$

# %%
import requests
import json

# %%
# 
currencies = df['currency'].unique()
rates = []


for i in currencies:
    response = requests.get('https://api.exchangerate.host/convert?from='+str(i)+'&to=COP')
    data = json.loads(response.text)
    data = list(data['info'].values())

    for i in data:
        rates.append(i)

currency_rate = dict(zip(currencies, rates))
currency_rate

df_rates = pd.DataFrame.from_dict(currency_rate, orient='index').reset_index(names = ['currency'])
df_rates
# Out:
#   currency            0
# 0      BRL   847.082809
# 1      USD  4557.426056
# 2      MXN   223.772083
# 3      EUR  4369.710159

# %%
#Testing
df = pd.merge(df,df_rates,on=['currency'])
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0 trans_date_trans_time           cc_num  \
# 0        171220      171220   2020-08-20 05:11:01  342952484382519
# 1        160693      160693   2020-08-16 20:51:36     577588686219
# 2        294642      294642   2020-10-10 13:39:15   30546453310167
#
#                             merchant        category     amt     first  \
# 0  fraud_Bernier, Streich and Jewess     grocery_net   10.89     Kayla
# 1                   fraud_Klocko LLC        misc_net  239.81     James
# 2                fraud_Adams-Barrows  health_fitness  123.84  Nicholas
#
#          last gender  ... city_pop                                 job  \
# 0       Jones      F  ...      647                         Comptroller
# 1  Strickland      M  ...      972  Public relations account executive
# 2        Tran      M  ...     7430       Scientist, research (medical)
#
#           dob                         trans_num   unix_time  merch_lat  \
# 0  1987-09-26  1edb6f526690e3d8402b2001c3d907e1  1376975461  42.764616
# 1  1997-10-23  994b2402d858ede43e6197b063b5c9e3  1376686296  39.686499
# 2  1955-01-13  4f71389a42a11cf51f3fedf65ea11953  1381412355  42.669160
#
#    merch_long is_fraud currency           0
# 0  -72.394134        0      BRL  847.082809
# 1  -78.596598        0      BRL  847.082809
# 2  -71.811038        0      BRL  847.082809
#
# [3 rows x 26 columns]

# %%
#Rename column 0 to rates, drop unnecesary columns ['Unnamed: 0.1', 'Unnamed: 0']

df = df.rename(columns={0:'rates'})
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis = 1, inplace = True)
list(df.columns)
# Out:
# ['trans_date_trans_time',
#  'cc_num',
#  'merchant',
#  'category',
#  'amt',
#  'first',
#  'last',
#  'gender',
#  'street',
#  'city',
#  'state',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'job',
#  'dob',
#  'trans_num',
#  'unix_time',
#  'merch_lat',
#  'merch_long',
#  'is_fraud',
#  'currency',
#  'rates']

# %%
df['amt_cop'] = df['rates'] * df['amt'] #from another currency to COP rates = number

# %%
df
# Out:
#       trans_date_trans_time               cc_num  \
# 0       2020-08-20 05:11:01      342952484382519
# 1       2020-08-16 20:51:36         577588686219
# 2       2020-10-10 13:39:15       30546453310167
# 3       2020-08-09 03:54:20     6538891242532018
# 4       2020-11-14 06:49:11  4400011257587661852
# ...                     ...                  ...
# 13428   2020-07-23 10:07:46      340951438290556
# 13429   2020-10-13 05:29:54     2288813824604479
# 13430   2020-09-07 21:23:04        4198470814557
# 13431   2020-10-04 14:20:00     4424338559877976
# 13432   2020-11-10 00:39:37     4683520018489354
#
#                                      merchant        category     amt  \
# 0           fraud_Bernier, Streich and Jewess     grocery_net   10.89
# 1                            fraud_Klocko LLC        misc_net  239.81
# 2                         fraud_Adams-Barrows  health_fitness  123.84
# 3                        fraud_McCullough LLC        misc_pos   34.14
# 4                         fraud_Miller-Harris        misc_net    9.66
# ...                                       ...             ...     ...
# 13428  fraud_Johnson, Runolfsdottir and Mayer        misc_net   40.38
# 13429                     fraud_Keeling-Crist        misc_pos  151.37
# 13430         fraud_Lehner, Mosciski and King        misc_net    7.90
# 13431                       fraud_Block-Hauck          travel    9.35
# 13432                      fraud_Zemlak Group        misc_net    8.06
#
#           first        last gender                           street  \
# 0         Kayla       Jones      F       6033 Young Track Suite 804
# 1         James  Strickland      M               25454 Leonard Lake
# 2      Nicholas        Tran      M       672 Randall Burg Suite 551
# 3          Jodi   Rodriguez      F          5796 Lee Coves Apt. 286
# 4       Marissa      Powell      F                  474 Allen Haven
# ...         ...         ...    ...                              ...
# 13428     Maria      Garcia      F               865 Thomas Village
# 13429   Barbara      Norman      F            6278 Stephanie Unions
# 13430  Christie  Williamson      F                  519 Jerry Views
# 13431    Denise     Barnett      F              23220 Eaton Harbors
# 13432   Charles    Carrillo      M  17547 Stephen Turnpike Apt. 846
#
#                 city  ...                                    job         dob  \
# 0        East Canaan  ...                            Comptroller  1987-09-26
# 1      Spring Church  ...     Public relations account executive  1997-10-23
# 2            Belmont  ...          Scientist, research (medical)  1955-01-13
# 3       Walnut Ridge  ...  Engineer, control and instrumentation  1977-03-23
# 4         North Loup  ...                      Nurse, children's  1980-09-15
# ...              ...  ...                                    ...         ...
# 13428     Orangeburg  ...                        Records manager  1971-07-02
# 13429  New York City  ...                              Herbalist  1981-08-29
# 13430          Avoca  ...                  Engineering geologist  1971-08-20
# 13431          Kirby  ...                  Private music teacher  1957-11-12
# 13432      Hawthorne  ...              Editor, magazine features  1995-04-19
#
#                               trans_num   unix_time  merch_lat  merch_long  \
# 0      1edb6f526690e3d8402b2001c3d907e1  1376975461  42.764616  -72.394134
# 1      994b2402d858ede43e6197b063b5c9e3  1376686296  39.686499  -78.596598
# 2      4f71389a42a11cf51f3fedf65ea11953  1381412355  42.669160  -71.811038
# 3      4f3871b7750fc312f0c98619ada6b44a  1376020460  35.351900  -89.983282
# 4      6c97b525b2f27b4909294402350e1ba5  1384411751  41.395599  -97.910305
# ...                                 ...         ...        ...         ...
# 13428  bd0079745e0ac6a57dbefb32e30787d0  1374574066  40.520192  -74.441980
# 13429  198e2fa63765e0a47fc4e88678b12ed9  1381642194  40.580356  -74.461230
# 13430  8407f164adb96684ab5551d1c2c786c2  1378588984  40.479614  -95.352894
# 13431  e8b225a339d2cbe641aa021f2b2271a4  1380896400  41.221618  -84.005962
# 13432  4de625a88aabab3af7d71a0d66ea0749  1384043977  33.145838 -117.366878
#
#       is_fraud currency        rates        amt_cop
# 0            0      BRL   847.082809    9224.731790
# 1            0      BRL   847.082809  203138.928426
# 2            0      BRL   847.082809  104902.735067
# 3            0      BRL   847.082809   28919.407099
# 4            0      BRL   847.082809    8182.819935
# ...        ...      ...          ...            ...
# 13428        0      EUR  4369.710159  176448.896220
# 13429        0      EUR  4369.710159  661443.026768
# 13430        0      EUR  4369.710159   34520.710256
# 13431        0      EUR  4369.710159   40856.789987
# 13432        0      EUR  4369.710159   35219.863882
#
# [13433 rows x 25 columns]

# %% [markdown]
# 3.4 Calcule una nueva columna con los 6 primeros números de la columna ‘cc_num’ y llámela bin

# %%
df['bin'] = df['cc_num'].astype(str).str[:6] # create bin

# %%
df['bin'] = df['bin'].astype(int)

# %%
df.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# 3. 5 Calcule en una nueva columna en la misma tabla la cuenta de números de tarjeta únicos
# por ‘bin’ y por ‘merchant’ en toda la base

# %%
#Unique values between bin and merchant
test0 = df.groupby(['bin'])['merchant'].nunique()
df_test0 = pd.DataFrame(test0).reset_index(names = ['bin', 'merchant'])
df_test0 = df_test0.set_index('bin')
df_test0
df= pd.merge(df, df_test0, on =['bin'])
df.head(3)
# Out:
#   trans_date_trans_time           cc_num                         merchant_x  \
# 0   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 1   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 2   2020-07-21 19:36:23  342952484382519                   fraud_Schumm PLC
#
#          category    amt  first   last gender                      street  \
# 0     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 1     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 2  health_fitness  14.44  Kayla  Jones      F  6033 Young Track Suite 804
#
#           city  ...                         trans_num   unix_time  merch_lat  \
# 0  East Canaan  ...  1edb6f526690e3d8402b2001c3d907e1  1376975461  42.764616
# 1  East Canaan  ...  1edb6f526690e3d8402b2001c3d907e1  1376975461  42.764616
# 2  East Canaan  ...  118dd4f625a5682334eb6520b96ec395  1374435383  42.315580
#
#    merch_long  is_fraud currency       rates       amt_cop     bin  merchant_y
# 0  -72.394134         0      BRL  847.082809   9224.731790  342952          30
# 1  -72.394134         0      BRL  847.082809   9224.731790  342952          30
# 2  -74.130053         0      BRL  847.082809  12231.875762  342952          30
#
# [3 rows x 27 columns]

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
#merchant_y is Merchant
# Renames a Header in the Dataframe
df = df.rename(columns={'merchant_x':'merchant', 'merchant_y':'Merchant'})
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'currency', 'rates', 'amt_cop', 'bin',
#        'Merchant'],
#       dtype='object')

# %%
#Unique values between bin and merchant
test0 = df.groupby(['cc_num'])['merchant'].nunique()
df_test0 = pd.DataFrame(test0).reset_index(names = ['cc_num', 'merchant'])
df_test0 = df_test0.set_index('cc_num')
#df_test0
df= pd.merge(df, df_test0, on =['cc_num'])
df.head(3)
# Out:
#   trans_date_trans_time           cc_num                         merchant_x  \
# 0   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 1   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 2   2020-07-21 19:36:23  342952484382519                   fraud_Schumm PLC
#
#          category    amt  first   last gender                      street  \
# 0     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 1     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 2  health_fitness  14.44  Kayla  Jones      F  6033 Young Track Suite 804
#
#           city  ...   unix_time  merch_lat  merch_long  is_fraud  currency  \
# 0  East Canaan  ...  1376975461  42.764616  -72.394134         0       BRL
# 1  East Canaan  ...  1376975461  42.764616  -72.394134         0       BRL
# 2  East Canaan  ...  1374435383  42.315580  -74.130053         0       BRL
#
#         rates       amt_cop     bin  Merchant  merchant_y
# 0  847.082809   9224.731790  342952        30          30
# 1  847.082809   9224.731790  342952        30          30
# 2  847.082809  12231.875762  342952        30          30
#
# [3 rows x 28 columns]

# %%
df = df.rename(columns={'merchant_x':'merchant', 'merchant_y':'Calculo'})
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'currency', 'rates', 'amt_cop', 'bin',
#        'Merchant', 'Calculo'],
#       dtype='object')

# %%
df.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# 3.6. De manera similar, en otra columna, calcule cuántos códigos ZIP se registraron por cada
# ciudad.

# %%
test0 = df.groupby(['city'])['zip'].nunique()
#test0 

df_test0 = pd.DataFrame(test0).reset_index(names = ['city', 'zip'])
#
df_test0 = df_test0.set_index('city')
#df_test0
df= pd.merge(df, df_test0, on =['city']) 
df.head(3)
# Out:
#   trans_date_trans_time           cc_num                           merchant  \
# 0   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 1   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 2   2020-07-21 19:36:23  342952484382519                   fraud_Schumm PLC
#
#          category    amt  first   last gender                      street  \
# 0     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 1     grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 2  health_fitness  14.44  Kayla  Jones      F  6033 Young Track Suite 804
#
#           city  ...  merch_lat  merch_long  is_fraud  currency       rates  \
# 0  East Canaan  ...  42.764616  -72.394134         0       BRL  847.082809
# 1  East Canaan  ...  42.764616  -72.394134         0       BRL  847.082809
# 2  East Canaan  ...  42.315580  -74.130053         0       BRL  847.082809
#
#         amt_cop     bin Merchant  Calculo  zip_y
# 0   9224.731790  342952       30       30      1
# 1   9224.731790  342952       30       30      1
# 2  12231.875762  342952       30       30      1
#
# [3 rows x 29 columns]

# %%
#Renames zip_y counter by city

df = df.rename(columns={'zip_x':'zip', 'zip_y':'zip_by_city'})
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'currency', 'rates', 'amt_cop', 'bin',
#        'Merchant', 'Calculo', 'zip_by_city'],
#       dtype='object')

# %% [markdown]
# 3.7. En columnas diferentes, calcule el número de transacciones que cada pagador (nombre
# y apellido) hizo en la misma hora y en el mismo día de la fecha de cada transacción.

# %%
from datetime import *

# %%
df['name'] = df['first'].astype(str) +' '+ df['last'] #new column to name
df['day'] = df['trans_date_trans_time'].dt.day_name() #new column to day name
df['hour'] = df['trans_date_trans_time'].dt.hour #new column to hour
df['date'] = df['trans_date_trans_time'].dt.date #new column to date
 
df.head(2)
# Out:
#   trans_date_trans_time           cc_num                           merchant  \
# 0   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 1   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
#
#       category    amt  first   last gender                      street  \
# 0  grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 1  grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
#
#           city  ...       rates     amt_cop     bin  Merchant  Calculo  \
# 0  East Canaan  ...  847.082809  9224.73179  342952        30       30
# 1  East Canaan  ...  847.082809  9224.73179  342952        30       30
#
#   zip_by_city         name       day  hour        date
# 0           1  Kayla Jones  Thursday     5  2020-08-20
# 1           1  Kayla Jones  Thursday     5  2020-08-20
#
# [2 rows x 33 columns]

# %%
df_ag1 = df.groupby(['name'])[['date']].agg({'date':'count'}) #grouping by same date and name
df_ag2 = df.groupby(['name'])[['hour']].agg({'hour':'count'}) #grouping by same hour and name

#merging
df = pd.merge(df, df_ag1, on =['name']) 
df = pd.merge(df, df_ag2, on =['name']) 
#rename columns
df = df.rename(columns={'date_x':'date', 'date_y':'date_counter', 'hour_x':'hour', 'hour_y':'hour_counter'})

# %% [markdown]
# 3.8. Asigne el valor 1 en la columna ‘is_fraud’ cuando los valores calculados en los tres puntos
# anteriores se ubiquen por encima del promedio. En caso contrario, deje los valores que
# ya están en esa variable.

# %%
df.describe(include = [np.number])
# Out:
#              cc_num           amt           zip           lat          long  \
# count  1.343300e+04  13433.000000  13433.000000  13433.000000  13433.000000
# mean   4.207385e+17     65.170153  48551.614755     38.562406    -90.160649
# std    1.313871e+18    169.067617  26856.164504      5.054902     13.769688
# min    6.041621e+10      1.000000   1257.000000     20.027100   -165.672300
# 25%    1.800365e+14      6.600000  25832.000000     34.703100    -96.727000
# 50%    3.523843e+15     27.790000  47838.000000     39.390000    -86.992000
# 75%    4.634956e+15     68.470000  71960.000000     41.838300    -80.158000
# max    4.992346e+18   5373.720000  99783.000000     65.689900    -67.950300
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud  \
# count  1.343300e+04  1.343300e+04  13433.000000  13433.000000  13433.000000
# mean   8.815250e+04  1.380680e+09     38.566527    -90.161811      0.004020
# std    2.885508e+05  5.183473e+06      5.091345     13.773298      0.063278
# min    2.300000e+01  1.371817e+09     19.057758   -166.611810      0.000000
# 25%    7.650000e+02  1.376039e+09     34.770579    -96.808228      0.000000
# 50%    2.691000e+03  1.380770e+09     39.431935    -87.204620      0.000000
# 75%    2.190200e+04  1.385869e+09     41.935190    -80.217256      0.000000
# max    2.906700e+06  1.388534e+09     66.644397    -67.002451      1.000000
#
#               rates       amt_cop            bin      Merchant       Calculo  \
# count  13433.000000  1.343300e+04   13433.000000  13433.000000  13433.000000
# mean    2512.537433  1.652542e+05  409412.413311     20.251619     19.491476
# std     1978.076939  5.310642e+05  119710.646388     10.580056      9.484530
# min      223.772083  2.237721e+02  180011.000000      1.000000      1.000000
# 25%      847.082809  7.908105e+03  351236.000000     13.000000     12.000000
# 50%     4369.710159  3.135509e+04  385804.000000     19.000000     19.000000
# 75%     4557.426056  1.476150e+05  474599.000000     26.000000     25.000000
# max     4557.426056  1.860942e+07  676372.000000     68.000000     51.000000
#
#         zip_by_city          hour  date_counter  hour_counter
# count  13433.000000  13433.000000  13433.000000  13433.000000
# mean       1.153726     11.944837     20.944614     20.944614
# std        0.451287      6.907045     10.757198     10.757198
# min        1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      6.000000     13.000000     13.000000
# 50%        1.000000     12.000000     20.000000     20.000000
# 75%        1.000000     18.000000     27.000000     27.000000
# max        4.000000     23.000000     57.000000     57.000000

# %%
mean_Merchant = df['Merchant'].mean()
mean_Calculo = df['Calculo'].mean()
mean_zip_by_city = df['zip_by_city'].mean()
mean_hour_counter = df['hour_counter'].mean()
mean_date_counter = df['date_counter'].mean()


for i in range(0, len(df)):
    if (df.loc[i, 'Merchant'] >= mean_Merchant or 
        df.loc[i, 'Calculo'] >= mean_Calculo or 
        df.loc[i, 'zip_by_city'] >= mean_zip_by_city or 
        df.loc[i, 'hour_counter'] >= mean_hour_counter or
        df.loc[i, 'date_counter'] >= mean_date_counter):

        df.loc[i, 'is_fraud'] = 1
    else:
        df.loc[i, 'is_fraud'] = 0

df.head(2)
# Out:
#   trans_date_trans_time           cc_num                           merchant  \
# 0   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
# 1   2020-08-20 05:11:01  342952484382519  fraud_Bernier, Streich and Jewess
#
#       category    amt  first   last gender                      street  \
# 0  grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
# 1  grocery_net  10.89  Kayla  Jones      F  6033 Young Track Suite 804
#
#           city  ...     bin  Merchant  Calculo  zip_by_city         name  \
# 0  East Canaan  ...  342952        30       30            1  Kayla Jones
# 1  East Canaan  ...  342952        30       30            1  Kayla Jones
#
#         day hour        date  date_counter  hour_counter
# 0  Thursday    5  2020-08-20            33            33
# 1  Thursday    5  2020-08-20            33            33
#
# [2 rows x 35 columns]

# %% [markdown]
# 3.9. En una nueva tabla, calcule para cada comercio (‘merchant’), el número de transacciones,
# la suma del monto de todas las transacciones en pesos colombianos, el número de
# fraudes, la suma del monto con fraude, el porcentaje de fraude por número de
# transacciones y por monto, el número de tarjetas distintas (‘cc_num’).

# %%
# copy from the original with the variables needed to make aggregations requiered

df2 = df[['merchant', 'cc_num', 'trans_date_trans_time', 'amt_cop', 'is_fraud']].copy()

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13433 entries, 0 to 13432
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   merchant               13433 non-null  object
#  1   cc_num                 13433 non-null  int64
#  2   trans_date_trans_time  13433 non-null  datetime64[ns]
#  3   amt_cop                13433 non-null  float64
#  4   is_fraud               13433 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# 3.9.1. Numero de transacciones

# %%
df_ag = df2.groupby(['merchant'])[['trans_date_trans_time']].agg({'trans_date_trans_time':'count'}) # number of transaction per merchant

df2= pd.merge(df2, df_ag, on =['merchant'])
df2 = df2.rename(columns={'trans_date_trans_time_x':'trans_date_trans_time', 'trans_date_trans_time_y':'trans_counter'}) #rename 
df2.head(2)
# Out:
#                             merchant           cc_num trans_date_trans_time  \
# 0  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
# 1  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
#
#       amt_cop  is_fraud  trans_counter
# 0  9224.73179         1             55
# 1  9224.73179         1             55

# %% [markdown]
# 3.9.2. Suma del monto de todas las transacciones en COP

# %%
df_ag = df2.groupby(['merchant'])[['amt_cop']].agg({'amt_cop':'sum'}) # total amount trans per merchant


df2= pd.merge(df2, df_ag, on =['merchant'])
df2 = df2.rename(columns={'amt_cop_x':'amt_cop', 'amt_cop_y':'total_amt'}) #rename 
df2.head(2)
# Out:
#                             merchant           cc_num trans_date_trans_time  \
# 0  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
# 1  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
#
#       amt_cop  is_fraud  trans_counter     total_amt
# 0  9224.73179         1             55  8.350098e+06
# 1  9224.73179         1             55  8.350098e+06

# %% [markdown]
# 3.9.3. Número de fraudes

# %%
df_ag = df2.groupby(['merchant'])[['is_fraud']].agg({'is_fraud':'sum'}) # total fraud per merchant


df2= pd.merge(df2, df_ag, on =['merchant'])
df2 = df2.rename(columns={'is_fraud_x':'is_fraud', 'is_fraud_y':'fraud_counter'}) #rename 
df2.head(2)
# Out:
#                             merchant           cc_num trans_date_trans_time  \
# 0  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
# 1  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
#
#       amt_cop  is_fraud  trans_counter     total_amt  fraud_counter
# 0  9224.73179         1             55  8.350098e+06             36
# 1  9224.73179         1             55  8.350098e+06             36

# %% [markdown]
# 3.9.4. Suma del monto con fraude

# %%
mask = df2[df2['is_fraud'] == 1]

df_ag = mask.groupby(['merchant'])[['amt_cop']].agg({'amt_cop':'sum'}) 

df2 = pd.merge(df2, df_ag, on =['merchant'])
df2 = df2.rename(columns={'amt_cop_x':'amt_cop', 'amt_cop_y':'fraud_amt'}) #rename 
df2.head(2)
# Out:
#                             merchant           cc_num trans_date_trans_time  \
# 0  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
# 1  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
#
#       amt_cop  is_fraud  trans_counter     total_amt  fraud_counter  \
# 0  9224.73179         1             55  8.350098e+06             36
# 1  9224.73179         1             55  8.350098e+06             36
#
#       fraud_amt
# 0  4.232371e+06
# 1  4.232371e+06

# %% [markdown]
# 3.9.5. El porcentaje de fraude por número de
# transacciones y por monto

# %%
df2['perc_fraud_by_trans'] = (df2.trans_counter * df2.fraud_counter)//100
df2['perc_fraud_amt'] = (df2.fraud_amt*100)//df2.total_amt

# %%
df2
# Out:
#                                  merchant               cc_num  \
# 0       fraud_Bernier, Streich and Jewess      342952484382519
# 1       fraud_Bernier, Streich and Jewess      342952484382519
# 2       fraud_Bernier, Streich and Jewess  4587657402165341815
# 3       fraud_Bernier, Streich and Jewess     4191109180926792
# 4       fraud_Bernier, Streich and Jewess     6523180720198790
# ...                                   ...                  ...
# 13428  fraud_Hagenes, Hermann and Stroman     3560336828629935
# 13429  fraud_Hagenes, Hermann and Stroman       30373802285317
# 13430  fraud_Hagenes, Hermann and Stroman     3560725013359375
# 13431  fraud_Hagenes, Hermann and Stroman      372246459334925
# 13432  fraud_Hagenes, Hermann and Stroman     4104312520615374
#
#       trans_date_trans_time       amt_cop  is_fraud  trans_counter  \
# 0       2020-08-20 05:11:01  9.224732e+03         1             55
# 1       2020-08-20 05:11:01  9.224732e+03         1             55
# 2       2020-12-29 09:23:42  3.007497e+03         1             55
# 3       2020-09-13 06:26:06  9.671429e+03         1             55
# 4       2020-12-06 07:50:27  2.890320e+05         0             55
# ...                     ...           ...       ...            ...
# 13428   2020-09-21 20:04:59  9.801217e+02         0             34
# 13429   2020-08-15 23:21:46  5.556863e+03         0             34
# 13430   2020-09-06 21:50:54  7.451610e+02         1             34
# 13431   2020-09-13 13:59:04  1.075795e+03         0             34
# 13432   2020-08-18 22:43:35  1.976054e+06         0             34
#
#           total_amt  fraud_counter     fraud_amt  perc_fraud_by_trans  \
# 0      8.350098e+06             36  4.232371e+06                   19
# 1      8.350098e+06             36  4.232371e+06                   19
# 2      8.350098e+06             36  4.232371e+06                   19
# 3      8.350098e+06             36  4.232371e+06                   19
# 4      8.350098e+06             36  4.232371e+06                   19
# ...             ...            ...           ...                  ...
# 13428  2.225262e+07             14  1.794025e+07                    4
# 13429  2.225262e+07             14  1.794025e+07                    4
# 13430  2.225262e+07             14  1.794025e+07                    4
# 13431  2.225262e+07             14  1.794025e+07                    4
# 13432  2.225262e+07             14  1.794025e+07                    4
#
#        perc_fraud_amt
# 0                50.0
# 1                50.0
# 2                50.0
# 3                50.0
# 4                50.0
# ...               ...
# 13428            80.0
# 13429            80.0
# 13430            80.0
# 13431            80.0
# 13432            80.0
#
# [13433 rows x 11 columns]

# %%
print(df2.perc_fraud_amt.unique())
print(df2.perc_fraud_by_trans.unique())
# Out:
# [50. 46. 13. 44. 53. 37. 71. 52. 78. 33. 40.  0. 90. 57. 88. 70. 79. 77.
#  69. 41. 59. 66. 74. 65. 45.  9. 49. 28. 60. 67. 75. 72. 82. 54. 43. 56.
#  63. 38. 85. 80. 64. 55. 29. 32. 12.  3. 34. 36. 89. 73. 35.  1. 97. 16.
#  92. 48. 26. 51. 30. 31. 68. 58. 62. 47.  4. 19. 25. 83. 42. 76. 61. 39.
#  84. 10. 11. 96. 91.]
# [19 28 16 25 40 30  9 26 34 15  7 10 31 33 22 27 32 50  8 12  4 36 23 11
#   6 14 29 18 42 37 24 17  3  5 21 56 35 44 13 20  2]

# %% [markdown]
# 3.9.6. El número de tarjetas distintas (‘cc_num’)

# %%
df_ag = df2.groupby(['merchant'])['cc_num'].nunique()

df2= pd.merge(df2, df_ag, on =['merchant'])
df2 = df2.rename(columns={'cc_num_x':'cc_num', 'cc_num_y':'dist_card'}) #rename 
df2.head(2)
# Out:
#                             merchant           cc_num trans_date_trans_time  \
# 0  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
# 1  fraud_Bernier, Streich and Jewess  342952484382519   2020-08-20 05:11:01
#
#       amt_cop  is_fraud  trans_counter     total_amt  fraud_counter  \
# 0  9224.73179         1             55  8.350098e+06             36
# 1  9224.73179         1             55  8.350098e+06             36
#
#       fraud_amt  perc_fraud_by_trans  perc_fraud_amt  dist_card
# 0  4.232371e+06                   19            50.0         50
# 1  4.232371e+06                   19            50.0         50

# %%
print(df2.dist_card.unique())
# Out:
# [ 50  72  58  60  85  67  36  64  61  56  68  53  43  69  33  71  51  74
#   55  84  54  34  48  44  79  46  66  39  47  52  30  73  70  41  45  59
#   35  29  83  28  23  32  31  62  57  63  86  38  42  75 101  22  25  40
#   49  81  26  27  37  24  76]

# %%
df2.columns
# Out:
# Index(['merchant', 'cc_num', 'trans_date_trans_time', 'amt_cop', 'is_fraud',
#        'trans_counter', 'total_amt', 'fraud_counter', 'fraud_amt',
#        'perc_fraud_by_trans', 'perc_fraud_amt', 'dist_card'],
#       dtype='object')

# %% [markdown]
# ## 4. Cree una tabla en la base de datos con el resultado del punto anterior

# %%
#!pip3 install sqlalchemy

# %%
#sql = ("""INSERT INTO BI_table (merchant, cc_num, trans_date_trans_time, amt_cop, is_fraud, trans_counter, total_amt, fraud_counter, fraud_amt, perc_fraud_by_trans, perc_fraud_amt, dist_card) VALUES 
# ('%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s')""" %(str, int, datetime, float, int, int, float, int, float, int, float, int))

# %%
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Dropping EMPLOYEE table if already exists.
cursor.execute("DROP TABLE IF EXISTS BI_table")

#Creating table as per requirement
sql ='''CREATE TABLE BI_table (
   merchant CHAR(200) NOT NULL PRIMARY KEY,
   cc_num INT(30),
   trans_date_trans_time DATETIME,
   amt_cop FLOAT,
   is_fraud INT(30),
   trans_counter INT(30),
   total_amt FLOAT,
   fraud_counter INT(30),
   fraud_amt FLOAT,
   perc_fraud_by_trans FLOAT,
   perc_fraud_amt FLOAT,
   dist_card INT(30)
)'''
cursor.execute(sql)
# Out:
# 0

# %%
#converting dataframe to tuple
dataframe = df2.to_records(index= False)
tupla = list(dataframe)

#inserting data to Mysql
sql = '''INSERT INTO BI_table (
  merchant, cc_num, trans_date_trans_time, 
  amt_cop, is_fraud, trans_counter, total_amt, 
  fraud_counter, fraud_amt, perc_fraud_by_trans, 
  perc_fraud_amt, dist_card) 
  VALUES('%s', %s, '%s', %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
);'''

#%(str, int, datetime, float, int, int, float, int, float, int, float, int))

cursor.executemany(sql, (tupla,))

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [183], line 16
#       6 sql = '''INSERT INTO BI_table (
#       7   merchant, cc_num, trans_date_trans_time,
#       8   amt_cop, is_fraud, trans_counter, total_amt,
#    (...)
#      11   VALUES('%s', %s, '%s', %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
#      12 ) ON DUPLICATE KEY UPDATE merchant=VALUES(merchant);'''
#      14 #%(str, int, datetime, float, int, int, float, int, float, int, float, int))
# ---> 16 cursor.executemany(sql, (tupla,))
#      18 conn.commit()
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
#     173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#    (...)
#     179         self._get_db().encoding,
#     180     )
# --> 182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     183 return self.rowcount
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:182, in <genexpr>(.0)
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
#     173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#    (...)
#     179         self._get_db().encoding,
#     180     )
# --> 182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     183 return self.rowcount
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:146, in Cursor.execute(self, query, args)
#     143 while self.nextset():
#     144     pass
# --> 146 query = self.mogrify(query, args)
#     148 result = self._query(query)
#     149 self._executed = query
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:125, in Cursor.mogrify(self, query, args)
#     122 conn = self._get_db()
#     124 if args is not None:
# --> 125     query = query % self._escape_args(args, conn)
#     127 return query
#
# TypeError: not all arguments converted during string formatting

# %%
dataframe
# Out:
# rec.array([('fraud_Bernier, Streich and Jewess',     342952484382519, '2020-08-20T05:11:01.000000000', 9.22473179e+03, 1, 55,  8350097.64853332, 36,  4232370.97831066, 19, 50., 50),
#            ('fraud_Bernier, Streich and Jewess',     342952484382519, '2020-08-20T05:11:01.000000000', 9.22473179e+03, 1, 55,  8350097.64853332, 36,  4232370.97831066, 19, 50., 50),
#            ('fraud_Bernier, Streich and Jewess', 4587657402165341815, '2020-12-29T09:23:42.000000000', 3.00749680e+03, 1, 55,  8350097.64853332, 36,  4232370.97831066, 19, 50., 50),
#            ...,
#            ('fraud_Hagenes, Hermann and Stroman',    3560725013359375, '2020-09-06T21:50:54.000000000', 7.45161036e+02, 1, 34, 22252616.85138098, 14, 17940246.57222882,  4, 80., 34),
#            ('fraud_Hagenes, Hermann and Stroman',     372246459334925, '2020-09-13T13:59:04.000000000', 1.07579517e+03, 0, 34, 22252616.85138098, 14, 17940246.57222882,  4, 80., 34),
#            ('fraud_Hagenes, Hermann and Stroman',    4104312520615374, '2020-08-18T22:43:35.000000000', 1.97605436e+06, 0, 34, 22252616.85138098, 14, 17940246.57222882,  4, 80., 34)],
#           dtype=[('merchant', 'O'), ('cc_num', '<i8'), ('trans_date_trans_time', '<M8[ns]'), ('amt_cop', '<f8'), ('is_fraud', '<i8'), ('trans_counter', '<i8'), ('total_amt', '<f8'), ('fraud_counter', '<i8'), ('fraud_amt', '<f8'), ('perc_fraud_by_trans', '<i8'), ('perc_fraud_amt', '<f8'), ('dist_card', '<i8')])

# %%
tupla
# Out:
# [('fraud_Bernier, Streich and Jewess', 342952484382519, '2020-08-20T05:11:01.000000000', 9224.73179001, 1, 55, 8350097.64853332, 36, 4232370.97831066, 19, 50., 50),
#  ('fraud_Bernier, Streich and Jewess', 342952484382519, '2020-08-20T05:11:01.000000000', 9224.73179001, 1, 55, 8350097.64853332, 36, 4232370.97831066, 19, 50., 50),
#  ('fraud_Bernier, Streich and Jewess', 4587657402165341815, '2020-12-29T09:23:42.000000000', 3007.49679552, 1, 55, 8350097.64853332, 36, 4232370.97831066, 19, 50., 50),
#  ('fraud_Bernier, Streich and Jewess', 4191109180926792, '2020-09-13T06:26:06.000000000', 9671.42942726, 1, 55, 8350097.64853332, 36, 4232370.97831066, 19, 50., 50),
#  ('fraud_Bernier, Streich and Jewess', 6523180720198790, '2020-12-06T07:50:27.000000000', 289031.96047152, 0, 55, 8350097.64853332, 36, 4232370.97831066, 19, 50., 50),
#  ('fraud_Bernier, Streich and Jewess', 
 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 581686439828, '2020-07-27T15:46:48.000000000', 67723.35119216, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 4683638447911, '2020-12-22T05:18:18.000000000', 158751.57007647, 0, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 6011109736646996, '2020-12-02T08:12:06.000000000', 71663.2466076, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 6011104316292105, '2020-08-10T15:41:24.000000000', 14128.0207736, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 2242542703101233, '2020-08-31T13:37:18.000000000', 95271.40352823, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 2242542703101233, '2020-09-05T20:32:48.000000000', 1057775.73818913, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 3502088871723054, '2020-08-28T21:34:21.000000000', 30107.30299551, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ('fraud_Lehner, Reichert and Mills', 3598215285024754, '2020-12-03T01:23:24.000000000', 7996.56959097, 1, 73, 9160648.53847839, 46, 6431230.98681146, 33, 70., 71),
#  ...]

# %%
# import the module
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://root:BDnotengo.26@localhost/testfraud"  
                      .format(user="root", pw="BDnotengo.26", 
                      db="testfraud"))
# Insert whole DataFrame into MySQL
df2.to_sql('BI_table', con = engine, if_exists = 'append', chunksize = 1000,index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [51], line 9
#       5 engine = create_engine("mysql+pymysql://root:BDnotengo.26@localhost/testfraud"
#       6                       .format(user="root", pw="BDnotengo.26",
#       7                       db="testfraud"))
#       8 # Insert whole DataFrame into MySQL
# ----> 9 df2.to_sql('BI_table', con = engine, if_exists = 'append', chunksize = 1000,index=False)
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2986, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2829 """
#    2830 Write records stored in a DataFrame to a SQL database.
#    2831
#    (...)
#    2982 [(1,), (None,), (2,)]
#    2983 """  # noqa:E501
#    2984 from pandas.io import sql
# -> 2986 return sql.to_sql(
#    2987     self,
#    2988     name,
#    2989     con,
#    2990     schema=schema,
#    2991     if_exists=if_exists,
#    2992     index=index,
#    2993     index_label=index_label,
#    2994     chunksize=chunksize,
#    2995     dtype=dtype,
#    2996     method=method,
#    2997 )
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:696, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     691 elif not isinstance(frame, DataFrame):
#     692     raise NotImplementedError(
#     693         "'frame' argument should be either a Series or a DataFrame"
#     694     )
# --> 696 return pandas_sql.to_sql(
#     697     frame,
#     698     name,
#     699     if_exists=if_exists,
#     700     index=index,
#     701     index_label=index_label,
#     702     schema=schema,
#     703     chunksize=chunksize,
#     704     dtype=dtype,
#     705     method=method,
#     706     engine=engine,
#     707     **engine_kwargs,
#     708 )
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:1751, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
#    1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    (...)
#    1748     **engine_kwargs,
#    1749 )
# -> 1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File c:\Users\isabe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:1662, in SQLDatabase.check_case_sensitive(self, name, schema)
#    1652 if name not in table_names:
#    1653     msg = (
#    1654         f"The provided table name '{name}' is not found exactly as "
#    1655         "such in the database after writing the table, possibly "
#    1656         "due to case sensitivity issues. Consider using lower "
#    1657         "case table names."
#    1658     )
#    1659     warnings.warn(
#    1660         msg,
#    1661         UserWarning,
# -> 1662         stacklevel=find_stack_level(inspect.currentframe()),
#    1663     )
#
# AttributeError: 'function' object has no attribute 'currentframe'
